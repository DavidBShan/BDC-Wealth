# %%
# !pip3 install ipykernel
# !pip3 install --upgrade nbformat
# Out:
# Requirement already satisfied: ipykernel in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (6.29.3)
# Requirement already satisfied: appnope in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipykernel) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipykernel) (8.22.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipykernel) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipykernel) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipykernel) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipykernel) (23.2)
# Requirement already satisfied: psutil in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipykernel) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipykernel) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipykernel) (6.4)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipykernel) (5.14.1)
# Requirement already satisfied: decorator in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel) (2.17.2)
# Requirement already satisfied: stack-data in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from jupyter-client>=6.1.12->ipykernel) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel) (0.2.2)
# Requirement already satisfied: nbformat in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbformat) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from nbformat) (4.21.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from nbformat) (5.7.1)
# Requirement already satisfied: traitlets>=5.1 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from nbformat) (5.14.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from jsonschema>=2.6->nbformat) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from jsonschema>=2.6->nbformat) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from jsonschema>=2.6->nbformat) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from jsonschema>=2.6->nbformat) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/davidshan/Library/Python/3.12/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.2.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('./lstm_datasets/cdi_predictions_w_infrastructure.csv')

# %%
plt.figure(figsize=(12, 6))
top_10_countries = df.nlargest(10, '2024 CDI')
for _, row in top_10_countries.iterrows():
    plt.plot(['2024', '2025', '2026', '2027', '2028'], 
             row[['2024 CDI', '2025 CDI', '2026 CDI', '2027 CDI', '2028 CDI']], 
             marker='o', 
             label=row['Country'])
plt.title('CDI Predictions for Top 10 Countries (2024-2028)')
plt.xlabel('Year')
plt.ylabel('CDI Score')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
changes_df = df.set_index('Country')[['2024 CDI', '2028 CDI']].pct_change(axis=1)['2028 CDI']
changes_df = changes_df.sort_values(ascending=False)
top_20_changes = changes_df.head(20)
sns.heatmap(df.set_index('Country').loc[top_20_changes.index], 
            cmap='YlOrRd', 
            annot=True, 
            fmt='.1f')
plt.title('CDI Heatmap for Top 20 Countries with Highest Change')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
top_bottom = pd.concat([df.nlargest(10, '2028 CDI'), df.nsmallest(10, '2028 CDI')])
sns.barplot(data=top_bottom, x='Country', y='2028 CDI')
plt.xticks(rotation=45, ha='right')
plt.title('Top and Bottom 10 Countries by 2028 CDI')
plt.tight_layout()
plt.show()

# %%
fig = px.choropleth(df, 
                    locations='Country', # country names
                    locationmode='country names',
                    color='2024 CDI',
                    hover_name='Country',
                    hover_data=['2024 CDI', '2028 CDI'],
                    color_continuous_scale='RdYlBu',
                    title='Global CDI Scores 2024')

# Update layout
fig.update_layout(
    title_x=0.5,
    geo=dict(showframe=False,
             showcoastlines=True,
             projection_type='equirectangular'),
    width=1000,
    height=600
)

fig.show()

# %%
plt.figure(figsize=(12, 6))
top_bottom = pd.concat([df.nlargest(10, '2028 CDI'), df.nsmallest(10, '2028 CDI')])
sns.barplot(data=top_bottom, x='Country', y='2028 CDI')
plt.xticks(rotation=45, ha='right')
plt.title('Top and Bottom 10 Countries by 2028 CDI')
plt.tight_layout()
plt.show()

# %%
df_melted = df.melt(id_vars=['Country'], 
                    value_vars=['2024 CDI', '2025 CDI', '2026 CDI', '2027 CDI', '2028 CDI'],
                    var_name='Year', 
                    value_name='CDI')

fig_animated = px.choropleth(df_melted,
                            locations='Country',
                            locationmode='country names',
                            color='CDI',
                            animation_frame='Year',
                            hover_name='Country',
                            color_continuous_scale='RdYlBu',
                            title='Global CDI Scores Evolution (2024-2028)')

# Update layout
fig_animated.update_layout(
    title_x=0.5,
    geo=dict(showframe=False,
             showcoastlines=True,
             projection_type='equirectangular'),
    width=1000,
    height=600
)

fig_animated.show()
# Out:
# /Users/davidshan/Library/Python/3.12/lib/python/site-packages/plotly/express/_core.py:2065: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
